# %%
import shutil

def main(json_file, output_folder, original_image_dir):
    # Load COCO JSON annotations
    with open(json_file, 'r') as f:
        data = json.load(f)

    images = data['images'] 
    # Ensure the output directory exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for img in images:
        # Copy original images to the specified folder
        original_image_path = os.path.join(original_image_dir, img['file_name'])

        new_image_path = os.path.join(output_folder,"{}.png".format(img["id"]))
        shutil.copy2(original_image_path, new_image_path)
        # print(f"Copied original image with a new name to {new_image_path}")

if __name__ == '__main__':
    original_image_dir = 'train'  # Where your original images are stored
    json_file = '/Users/harishsatheesh/Clothing-Style-transfer/train/_annotations.coco.json'
    output_folder = 'images'  
    main(json_file,output_folder, original_image_dir)

# %%
#WORKING
import json
import numpy as np
import skimage
import os
import shutil
from PIL import Image
import skimage.draw

def create_mask(image_info, annotations, output_folder):
    # Load the original image
    original_image_path = os.path.join(original_image_dir, "{}.png".format(image_info['id']))
    original_img = Image.open(original_image_path)

    # Create a mask as a numpy array with transparency (RGBA)
    mask_np = np.zeros((image_info['height'], image_info['width'], 4), dtype=np.uint8)  # RGBA format
    # Iterate through annotations
    for ann in annotations:
        if ann['image_id'] == image_info['id']:
            # Extract segmentation polygon
            for seg in ann['segmentation']:
                # Convert polygons to a binary mask and add it to the main mask
                rr, cc = skimage.draw.polygon(seg[1::2], seg[0::2], mask_np.shape[:2])
                # Get the original RGB pixel values from the loaded image
                original_pixels = np.array(original_img)
                # Assign original pixel values to the mask, including transparency (alpha channel)
                mask_np[rr, cc, :3] = original_pixels[rr, cc] 
                mask_np[rr, cc, 3] = 255  # Set alpha channel to fully opaque

    # Save the numpy array as a PNG image with transparency
    mask_path = os.path.join(output_folder, "{}.png".format(image_info['id']).replace(".png", '_mask.png'))
    mask_img = Image.fromarray(mask_np, mode='RGBA')  # Use mode 'RGBA' for color images with transparency
    mask_img.save(mask_path)
# Example usage:
# create_mask(image_info, annotations, output_folder, original_image_dir)

    # Display the mask
    # mask_img.show() #remember to comment this out before creating masks for all images
    print(f"Saved mask for {image_info['file_name']} to {mask_path}")

def main(json_file, mask_output_folder, image_output_folder, original_image_dir):
    # Load COCO JSON annotations
    with open(json_file, 'r') as f:
        data = json.load(f)

    images = data['images']  # Process only the first 4 images
    annotations = data['annotations']

    # Ensure the output directories exist
    if not os.path.exists(mask_output_folder):
        os.makedirs(mask_output_folder)
    if not os.path.exists(image_output_folder):
        os.makedirs(image_output_folder)

    for img in images:
        # Create the masks, append them to the mask output dir
        create_mask(img, annotations, mask_output_folder)

        # # Copy original images to the specified folder
        # original_image_path = os.path.join(original_image_dir,"{}.png".format(img["id"]))

        # new_image_path = os.path.join(image_output_folder,"{}.png".format(img["id"]))
        # shutil.copy2(original_image_path, new_image_path)
        # print(f"Copied original image to {new_image_path}")

if __name__ == '__main__':
    original_image_dir = 'images'  # Where ur original images are stored
    json_file = 'train/_annotations.coco.json'
    mask_output_folder = 'masks/'  #output mask images
    image_output_folder = 'renamed_images'  #output corresponding images 
    main(json_file, mask_output_folder, image_output_folder, original_image_dir)
# Out:
# Copied original image to renamed_images/17.png
# Saved mask for c33e32269bd5a22d492a32b95ccada95_jpg.rf.e13449a656e950a19dccc26bbce5abe1.jpg to masks/18_mask.png
# Copied original image to renamed_images/18.png
# Saved mask for e778753e5302e8047fdddb88aeed0c37_jpg.rf.df14520368587dc32bccf49e70fd9765.jpg to masks/19_mask.png
# Copied original image to renamed_images/19.png
# Saved mask for cfc959561412f65791291a7cf5048c15_jpg.rf.e2dbd6821bd58a7b1256b18926e664ac.jpg to masks/20_mask.png
# Copied original image to renamed_images/20.png
# Saved mask for img_0118_jpeg.rf.e06835787ca57ef884d88c9d15a60da3.jpg to masks/21_mask.png
# Copied original image to renamed_images/21.png
# Saved mask for img_0088_jpeg.rf.e252576fe74fdceffd3f6daecebaaf09.jpg to masks/22_mask.png
# Copied original image to renamed_images/22.png
# Saved mask for d3ffb8841f721835559ecdedeefd2387_jpg.rf.dea5934efb1898b7f28edb7798e89934.jpg to masks/23_mask.png
# Copied original image to renamed_images/23.png
# Saved mask for img_0001_jpeg.rf.e4968bfeb290087b9b5b68ea965ab544.jpg to masks/24_mask.png
# Copied original image to renamed_images/24.png
# Saved mask for e615b5460711beea4a0b1e6e1c3e9df5_jpg.rf.e58a4eb3515723cd50fa5c65369e8801.jpg to masks/25_mask.png
# Copied original image to renamed_images/25.png
# Saved mask for 3847d09a2d4cd130c008c60fdd7832a1_jpg.rf.e598f92d64818f2f69d8b02d5d5541c8.jpg to masks/26_mask.png
# Copied original image to renamed_images/26.png
# Saved mask for img_0064_jpeg.rf.e49ee814723f5eef8654822f4a6038d9.jpg to masks/27_mask.png
# Copied original image to renamed_images/27.png
# Saved mask for ec3b46ac7b2255571c0af2f7d6ff4421_jpg.rf.e661a637d0b73fda0740c52b6613bf49.jpg to masks/28_mask.png
# Copied original image to renamed_images/28.png
# Saved mask for f90b0abbe660b9686600bfd2b19a0b71_jpg.rf.e5c12511281a28966cfc5002e421901c.jpg to masks/29_mask.png
# Copied original image to renamed_images/29.png
# Saved mask for d19bbafb0474aff8e0b42e2c4c57f68c_jpg.rf.e702c069c62b39e250b8e75be0139256.jpg to masks/30_mask.png
# Copied original image to renamed_images/30.png
# Saved mask for fca7000d1b2db825d5b56db79b95c61c_jpg.rf.e563946b6136b0f7a9a2ade06e8cbdf3.jpg to masks/31_mask.png
# Copied original image to renamed_images/31.png
# Saved mask for ef7ed6a21ce986cb12ee4421efa216df_jpg.rf.e600c2e2f1a30d42094929c812945258.jpg to masks/32_mask.png
# Copied original image to renamed_images/32.png
# Saved mask for img_0202_jpeg.rf.ea44b88c87f564c27ec9d4b9511c03bd.jpg to masks/33_mask.png
# Copied original image to renamed_images/33.png
# Saved mask for d7e2b1b248b86536e4f5fb9111ec0c28_jpg.rf.e8e159d224a394050742037e0bc5aff3.jpg to masks/34_mask.png
# Copied original image to renamed_images/34.png
# Saved mask for 1eec96671e8a5fb35bf350d5e7196bda_jpg.rf.e96578a53ce45672b49201e5505d5d81.jpg to masks/35_mask.png
# Copied original image to renamed_images/35.png
# Saved mask for 14f97e527ed398ebb8e13d6af178d941_jpg.rf.e76eb7bf9bae65375b8d8ee431859111.jpg to masks/36_mask.png
# Copied original image to renamed_images/36.png
# Saved mask for img_0022_jpeg.rf.eb4a4b5e2dbb4bbe98cbc3d34033ae75.jpg to masks/37_mask.png
# Copied original image to renamed_images/37.png
# Saved mask for c080362228fa5ea2bd57f38ab6f950e2_jpg.rf.e8a49638e1432920493eae204dc036c1.jpg to masks/38_mask.png
# Copied original image to renamed_images/38.png
# Saved mask for d3cf66e85e45aede8542d3c0d419b6ac_jpg.rf.ec14cda5d8166903c02e5dd29d1b01b2.jpg to masks/39_mask.png
# Copied original image to renamed_images/39.png
# Saved mask for img_0186_jpeg.rf.eab2507ba1af1f5ecc6af289e397834c.jpg to masks/40_mask.png
# Copied original image to renamed_images/40.png
# Saved mask for f17fd9050a7d16a084f93c11b8506bb5_jpg.rf.e7794c596e9d9cba09534f4f4394fbac.jpg to masks/41_mask.png
# Copied original image to renamed_images/41.png
# Saved mask for cb43bd1cf64a15ba6d0bea9e343247ed_jpg.rf.ed66c1a1ed7e202d85df548196377c3b.jpg to masks/42_mask.png
# Copied original image to renamed_images/42.png
# Saved mask for img_0097_jpeg.rf.ec17962f67a274f0d1428dd5eeed1945.jpg to masks/43_mask.png
# Copied original image to renamed_images/43.png
# Saved mask for d4ab71089868d3213a9a0edcbf469a8d_jpg.rf.ec64d2b6cad8596dba9c7610f63d52bc.jpg to masks/44_mask.png
# Copied original image to renamed_images/44.png
# Saved mask for fa9d0d5edd31d61640e21fafc6aaa2c2_jpg.rf.ed322dafe45d7c975f5cb6aad335b135.jpg to masks/45_mask.png
# Copied original image to renamed_images/45.png
# Saved mask for 2e45b6c8ce44c314132eb408d68ce7e0_jpg.rf.ec7a11c7cb9eb9cab6c69454122b25ef.jpg to masks/46_mask.png
# Copied original image to renamed_images/46.png
# Saved mask for ef9dae290756a8dbcb1cde404da00a1a_jpg.rf.eb411aab6c8e5eb4c71790d883a794f3.jpg to masks/47_mask.png
# Copied original image to renamed_images/47.png
# Saved mask for img_0159_jpeg.rf.ee68ffad583bde399f85f5862b2186ed.jpg to masks/48_mask.png
# Copied original image to renamed_images/48.png
# Saved mask for img_0110_jpeg.rf.ee921432b048eacb3644f2f85ce14d92.jpg to masks/49_mask.png
# Copied original image to renamed_images/49.png
# Saved mask for f0363390b953ebb61ae02ec459ea21b1_jpg.rf.ef5d42219b794555387050f4935de0f4.jpg to masks/50_mask.png
# Copied original image to renamed_images/50.png
# Saved mask for e10a8dac9a4b0e4bb4424593fe187953_jpg.rf.eec671f20b704d69cf55eb6e93bd74d6.jpg to masks/51_mask.png
# Copied original image to renamed_images/51.png
# Saved mask for img_0100_jpeg.rf.f00e0d28d0a3c02c6b6b2e02dc0db9f7.jpg to masks/52_mask.png
# Copied original image to renamed_images/52.png
# Copied original image to renamed_images/122.png
# Saved mask for 38fdac9188383dc9ceb7977ac6d82259_jpg.rf.2e5501e422bffe03fdff714d3b4e0a54.jpg to masks/123_mask.png
# Copied original image to renamed_images/123.png
# Saved mask for f24b318fd05a1bc7099f0bd83dce9a90_jpg.rf.305c855b2bf7d9e77c35dab2dd507294.jpg to masks/124_mask.png
# Copied original image to renamed_images/124.png
# Saved mask for cfe46db710175acbb37e5d12cc56d499_jpg.rf.2e4ab53530b28710fd3012ea76d192e9.jpg to masks/125_mask.png
# Copied original image to renamed_images/125.png
# Saved mask for img_0070_jpeg.rf.2d8348a92bf6638480dd65d36f663b96.jpg to masks/126_mask.png
# Copied original image to renamed_images/126.png
# Saved mask for f71e5303f0a10b85bf4bbc6c9cbee1ab_jpg.rf.2de5c99b12a897c4a87ae693288c8233.jpg to masks/127_mask.png
# Copied original image to renamed_images/127.png
# Saved mask for c6d8dcf46baab321a427db4f7e266168_jpg.rf.2f1192257cf1bc5f77cbe2f4f7488b0e.jpg to masks/128_mask.png
# Copied original image to renamed_images/128.png
# Saved mask for fd8b3471ca4273c30144cb8a13b4fc36_jpg.rf.3152dc239fb258aeae78893ef5e2232f.jpg to masks/129_mask.png
# Copied original image to renamed_images/129.png
# Saved mask for dcbbdfd8befcde17f00c35877fb20277_jpg.rf.301f5128ccc0e9ed1d61400c96a5be13.jpg to masks/130_mask.png
# Copied original image to renamed_images/130.png
# Saved mask for img_0148_jpeg.rf.322073f685b813950840fa34a0f68519.jpg to masks/131_mask.png
# Copied original image to renamed_images/131.png
# Saved mask for img_0003_jpeg.rf.333f07925c66a9d6058c9adcf70a988a.jpg to masks/132_mask.png
# Copied original image to renamed_images/132.png
# Saved mask for bb66c9d8c278dd1a8f50e58dd3108d0c_jpg.rf.33ebfeb4ee02923cb72279592c6134b2.jpg to masks/133_mask.png
# Copied original image to renamed_images/133.png
# Saved mask for 1ca6fb4b937bb1f34797d3315266a546_jpg.rf.336880eb251c6586e1bf3a549dfe5b67.jpg to masks/134_mask.png
# Copied original image to renamed_images/134.png
# Saved mask for f7f1160c7a945bf9f6a554213333b7bd_jpg.rf.328e87af3d48fb9196667fdb8dab8939.jpg to masks/135_mask.png
# Copied original image to renamed_images/135.png
# Saved mask for fbe39014a350272a1d2f8a50585594f2_jpg.rf.3432624d4869ee65f4212d0bf7ab13b0.jpg to masks/136_mask.png
# Copied original image to renamed_images/136.png
# Saved mask for c889c6521a8ca1d17073308ca9e56fc2_jpg.rf.2e758bac07b8a921119124fb00f0bc8f.jpg to masks/137_mask.png
# Copied original image to renamed_images/137.png
# Saved mask for d0a5016b11056c25872b94d28bc0322c_jpg.rf.344403e73c5b877c0a646cde741551d9.jpg to masks/138_mask.png
# Copied original image to renamed_images/138.png
# Saved mask for 1e7af28b45470cbbf44bbc07b716b1d1_jpg.rf.35b650263000d3fc7be1226d51ffd1fa.jpg to masks/139_mask.png
# Copied original image to renamed_images/139.png
# Saved mask for d37fd4b32e7008873d01508f21d45877_jpg.rf.3650dda7a82b4baa870c8f4d82a2124e.jpg to masks/140_mask.png
# Copied original image to renamed_images/140.png
# Saved mask for f692add639067c1f3617c472f5d503c2_jpg.rf.36b40b3e02766311c7a1f3a0c0b3683b.jpg to masks/141_mask.png
# Copied original image to renamed_images/141.png
# Saved mask for 0d98a538dcc1ae339c2e4cfd235b9509_jpg.rf.357c1d3d3d1ecd7ad1e799ae6f7f9d85.jpg to masks/142_mask.png
# Copied original image to renamed_images/142.png
# Saved mask for cb80d4d064c56174e07a8bc66c3fd601_jpg.rf.3478ee7f35717c043a5c2857a31280cb.jpg to masks/143_mask.png
# Copied original image to renamed_images/143.png
# Saved mask for 5f5e8dd2003101a233a31bfc1b940085_jpg.rf.376cafb3359a8151258d8db039977b92.jpg to masks/144_mask.png
# Copied original image to renamed_images/144.png
# Saved mask for c8e419891e3b5591f2acd756e6047411_jpg.rf.38796a4c3fbdc73672707e3bd77fe69f.jpg to masks/145_mask.png
# Copied original image to renamed_images/145.png
# Saved mask for img_0874_jpeg.rf.364d4fbf2fdaea20c82c6d440a773d91.jpg to masks/146_mask.png
# Copied original image to renamed_images/146.png
# Saved mask for 37370ccfad7a49a1121ad83eb0a39b87_jpg.rf.36bd76a9b095b92e15081e752e3b4d5f.jpg to masks/147_mask.png
# Copied original image to renamed_images/147.png
# Saved mask for 13eb38998d1db390780388635cc81d70_jpg.rf.3711c555fc1f3804c82b91af124a72ff.jpg to masks/148_mask.png
# Copied original image to renamed_images/148.png
# Saved mask for e1dfc67b430c393a50552a4226ef7364_jpg.rf.388e28f97a910983a0819393ac8a9be0.jpg to masks/149_mask.png
# Copied original image to renamed_images/149.png
# Saved mask for img_0260_jpeg.rf.38a13748c24d25a790ab59eb4a24d95f.jpg to masks/150_mask.png
# Copied original image to renamed_images/150.png
# Saved mask for img_0156_jpeg.rf.39afe2ae1c93861d8b7e6631df7c9a40.jpg to masks/151_mask.png
# Copied original image to renamed_images/151.png
# Saved mask for img_0337_jpeg.rf.3a1b65019d87bf21c8c2b8c5e85ad65c.jpg to masks/152_mask.png
# Copied original image to renamed_images/152.png
# Saved mask for 04f6e414deea516f05612aa595c7a65e_jpg.rf.3a8d4a11792c4e62dba5bc6c23739e45.jpg to masks/153_mask.png
# Copied original image to renamed_images/153.png
# Saved mask for f6092084a0174868cfb121b6750c96d2_jpg.rf.39eeaa160a3d7885cec23ac59cac7918.jpg to masks/154_mask.png
# Copied original image to renamed_images/154.png
# Saved mask for img_0171_jpeg.rf.3a47d68d7601989cbdb3cc1223325654.jpg to masks/155_mask.png
# Copied original image to renamed_images/155.png
# Saved mask for 176c976ed8edcf21eebef9de662adc18_jpg.rf.3abcdab72b51b9b37210b8066c98d17a.jpg to masks/156_mask.png
# Copied original image to renamed_images/156.png
# Saved mask for 4ed56e93ed6d3f48f669ef07e22d4ce5_jpg.rf.3ac89a41b9c364bda558002a4594937a.jpg to masks/157_mask.png
# Copied original image to renamed_images/157.png
# Saved mask for 2dfddd4c026c5dfbcf2556557e6290cc_jpg.rf.3b372cd1c53f81a88a8a17fa3c8611fa.jpg to masks/158_mask.png
# Copied original image to renamed_images/158.png
# Saved mask for img_0490_jpeg.rf.3baef6ddb5d79801f8e2e5e3f778e7eb.jpg to masks/159_mask.png
# Copied original image to renamed_images/159.png
# Saved mask for 8013b694ce0185715887693a5728c3aa_jpg.rf.3b7ce0271693a72c5bb5d0ab572a2c5e.jpg to masks/160_mask.png
# Copied original image to renamed_images/160.png
# Saved mask for de90e3f82e7a96e74dfc900b07caf5ab_jpg.rf.3ae2e0a471b32cc47bbf863961667714.jpg to masks/161_mask.png
# Copied original image to renamed_images/161.png
# Saved mask for 60a31121195ca0621a6bf6b01b6c9fcf_jpg.rf.3c22470932f92d5ff404ca0781526513.jpg to masks/162_mask.png
# Copied original image to renamed_images/162.png
# Saved mask for 5b1bea3ae9b3acc3eb31699269e212ca_jpg.rf.3c3d9552e4f82f2adf6c0ff65c08ab1d.jpg to masks/163_mask.png
# Copied original image to renamed_images/163.png
# Saved mask for img_0666_jpeg.rf.3ca4fb36ef914e6c40d461af5511bed9.jpg to masks/164_mask.png
# Copied original image to renamed_images/164.png
# Saved mask for aa79d470d20e275afb10698ff96cbc10_jpg.rf.3d52239f277083e76a4f762597802485.jpg to masks/165_mask.png
# Copied original image to renamed_images/165.png
# Saved mask for img_0045_jpeg.rf.3e75b7d16bfc1bc11a289a9b70a7d6c3.jpg to masks/166_mask.png
# Copied original image to renamed_images/166.png
# Saved mask for ed25ee9ad312276a593ad8bd4c7cb66c_jpg.rf.3ec14ca09bd5fb658ba8f9368676f3f4.jpg to masks/167_mask.png
# Copied original image to renamed_images/167.png
# Saved mask for d15a9ee27ee2180fee5ba2447d6c7939_jpg.rf.3d7d683af37d1ebbe3f56ca60ade773f.jpg to masks/168_mask.png
# Copied original image to renamed_images/168.png
# Saved mask for e2a1712cc3928d83e0339e5cb3832fec_jpg.rf.3f23e9b5d552db38d494eda1f36733df.jpg to masks/169_mask.png
# Copied original image to renamed_images/169.png
# Saved mask for f2fdd8cd855c9ba793b4d92bf979b80e_jpg.rf.3f5abb7cbe0185b167ae86a6cb9a61cf.jpg to masks/170_mask.png
# Copied original image to renamed_images/170.png
# Saved mask for img_0147_jpeg.rf.3f3861502d9440f41e24cddc5faa95c9.jpg to masks/171_mask.png
# Copied original image to renamed_images/171.png
# Saved mask for a56c94b934f4bb83c844244cc54bc5b5_jpg.rf.3f6702d8e7e383b733398c8273fabc97.jpg to masks/172_mask.png
# Copied original image to renamed_images/172.png
# Saved mask for 6129a289fa99fd43988c56cf0271e345_jpg.rf.3fc156b27a11a700143b9e946dabddf4.jpg to masks/173_mask.png
# Copied original image to renamed_images/173.png
# Saved mask for a70857f8f76a18d097becc82eb33a9f1_jpg.rf.4119fb820be0ab313a3e5370e3d9f992.jpg to masks/174_mask.png
# Copied original image to renamed_images/174.png
# Saved mask for 5569e07f788a17febbfa20b7d97d47cd_jpg.rf.3fe2841381a5ddbd738368854625c84d.jpg to masks/175_mask.png
# Copied original image to renamed_images/227.png
# Saved mask for fe09d8b640810d94062d049160eca1e1_jpg.rf.541a6851af1aa8c7bc3ce11ffde9a27e.jpg to masks/228_mask.png
# Copied original image to renamed_images/228.png
# Saved mask for d2577921e35bba15a9a907544b492ec8_jpg.rf.5476bcee2b7c3aa7cc70a7a44c33424f.jpg to masks/229_mask.png
# Copied original image to renamed_images/229.png
# Saved mask for dd0cc2051bc4dc84952775ef320830ac_jpg.rf.55cb68ba39a300acd8a4dcb4ce528878.jpg to masks/230_mask.png
# Copied original image to renamed_images/230.png
# Saved mask for img_0079_jpeg.rf.53d6bdb3d1de7da6b870edfcea9cdd4e.jpg to masks/231_mask.png
# Copied original image to renamed_images/231.png
# Saved mask for img_0987_jpeg.rf.5122506f4e3bc295f9be630ac6991049.jpg to masks/232_mask.png
# Copied original image to renamed_images/232.png
# Saved mask for ebb38e79797679a23f7959ebbe0337a0_jpg.rf.56d2bc5d2cc11ac181e4a2e5a5dc28d5.jpg to masks/233_mask.png
# Copied original image to renamed_images/233.png
# Saved mask for img_0950_jpeg.rf.56e321067c5617a52c952393fc444b77.jpg to masks/234_mask.png
# Copied original image to renamed_images/234.png
# Saved mask for 3e9a86f7c7424c09b4d0e1a76fe6f0ce_jpg.rf.57c9332160a0e9765c4b5d81ae05f195.jpg to masks/235_mask.png
# Copied original image to renamed_images/235.png
# Saved mask for img_0152_jpeg.rf.567a9892138d1d4db48024d0ab6f9599.jpg to masks/236_mask.png
# Copied original image to renamed_images/236.png
# Saved mask for dd4818adb730f88d9e57bb9c664812d9_jpg.rf.58a9332345f65a86905364cdc28c33e9.jpg to masks/237_mask.png
# Copied original image to renamed_images/237.png
# Saved mask for img_0165_jpeg.rf.58da5750f1d471194fe181564599cb6b.jpg to masks/238_mask.png
# Copied original image to renamed_images/238.png
# Saved mask for 3be3790820d624749b1dbfb956272265_jpg.rf.5972fc3e078cf1dc8e3da46b8ac0922c.jpg to masks/239_mask.png
# Copied original image to renamed_images/239.png
# Saved mask for f2d8b27b34c105ab8e0db9b153bbdbd1_jpg.rf.5825bf3c613a964462fd22149f36b467.jpg to masks/240_mask.png
# Copied original image to renamed_images/240.png
# Saved mask for c8bb6c6fde01f900ab9534e214f30de4_jpg.rf.59cd3e83b502dd9018e4bb0c8181d997.jpg to masks/241_mask.png
# Copied original image to renamed_images/241.png
# Saved mask for b2006174759a811aca6bd63e861dc741_jpg.rf.5a0be86198a2765d13c163905591c10c.jpg to masks/242_mask.png
# Copied original image to renamed_images/242.png
# Saved mask for 0dbd3f116ed02e39a2136824473b47a7_jpg.rf.5a1a042a3add9fa1b25c475918ee3cf9.jpg to masks/243_mask.png
# Copied original image to renamed_images/243.png
# Saved mask for 4e430921fc7a3cf3576f478fc8a43265_jpg.rf.5a228ee469828c59422a5d140df48704.jpg to masks/244_mask.png
# Copied original image to renamed_images/244.png
# Saved mask for e193ebbed15a2b391278754dfb41b4ee_jpg.rf.5a506c3faa272a1be02bd60c0a94cb06.jpg to masks/245_mask.png
# Copied original image to renamed_images/263.png
# Saved mask for dc348cf18c4ea3b836918d6eb93e910c_jpg.rf.649320db1989f0d2f9b830505ef8c590.jpg to masks/264_mask.png
# Copied original image to renamed_images/264.png
# Saved mask for f4034e5d4a52ae9fb3c3689d09f7cd2f_jpg.rf.6101b9ea6bba2939ef33874c5ecac37b.jpg to masks/265_mask.png
# Copied original image to renamed_images/265.png
# Saved mask for d32345e203eae6436a36869e770e4e7a_jpg.rf.651c58aa99129d79761a4fd4d70da821.jpg to masks/266_mask.png
# Copied original image to renamed_images/266.png
# Saved mask for img_0094_jpeg.rf.649eb80d9e010929a46f4a1ce3b4efce.jpg to masks/267_mask.png
# Copied original image to renamed_images/267.png
# Saved mask for d2e802de3a1d5f731f711440d59cfbe0_jpg.rf.65dd4f3dec2b9edccf579f02b048dde9.jpg to masks/268_mask.png
# Copied original image to renamed_images/268.png
# Saved mask for 9f2b43ca80f1efb145dc87cb63efbb85_jpg.rf.66c5113fc3600604c29ff376396f724d.jpg to masks/269_mask.png
# Copied original image to renamed_images/269.png
# Saved mask for ef29b8cb5fac955d116fcf42766bf3e1_jpg.rf.62556b3e6fd46caffab362e52c665462.jpg to masks/270_mask.png
# Copied original image to renamed_images/270.png
# Saved mask for d8a15c19d1717b794674e83c65152ca5_jpg.rf.664db1fb6ba68df8f73b94a0b354317e.jpg to masks/271_mask.png
# Copied original image to renamed_images/271.png
# Saved mask for img_0105_jpeg.rf.659d015503dbd7a879861b1660dda912.jpg to masks/272_mask.png
# Copied original image to renamed_images/272.png
# Saved mask for aa9e2de62fd6c1ddd43c9061844a3e59_jpg.rf.68187872020a35a8f83bbe7db68b4d63.jpg to masks/273_mask.png
# Copied original image to renamed_images/273.png
# Saved mask for 350932dd5559f9419cbd1fc1ae0e43e1_jpg.rf.66cb5c3b3e360697eaf230e9e443d8f1.jpg to masks/274_mask.png
# Copied original image to renamed_images/274.png
# Saved mask for img_0302_jpeg.rf.68ef1add2694c5cf8faa71db8748c61b.jpg to masks/275_mask.png
# Copied original image to renamed_images/275.png
# Saved mask for c7bce64a54a7b91d6f3686ef43f94d76_jpg.rf.68f4ad7089d844755848905df69ae8c1.jpg to masks/276_mask.png
# Copied original image to renamed_images/276.png
# Saved mask for img_0889_jpeg.rf.67a8e70433b0133cf5959955a4e10736.jpg to masks/277_mask.png
# Copied original image to renamed_images/277.png
# Saved mask for 0b48b477aa4075c5489c5bfb0df35017_jpg.rf.699612cdf2c6ab709ad28c3b719e7c73.jpg to masks/278_mask.png
# Copied original image to renamed_images/278.png
# Saved mask for 804a460e4bd0d666d51e84adc70f5490_jpg.rf.6928aac2a5dc768a985e40601336d69e.jpg to masks/279_mask.png
# Copied original image to renamed_images/279.png
# Saved mask for cc8f9e9034b24e6ce636b6b4694ef261_jpg.rf.6a7d746eb2f595bbbe9ce0ce38235cda.jpg to masks/280_mask.png
# Copied original image to renamed_images/280.png
# Copied original image to renamed_images/298.png
# Saved mask for img_0333_jpeg.rf.703358b2df61d6da1804c342d9e90acc.jpg to masks/299_mask.png
# Copied original image to renamed_images/299.png
# Saved mask for 2ccb0ad355225f62d6cd2144155eb915_jpg.rf.70f38627a75ce2686c1fd3a80b857024.jpg to masks/300_mask.png
# Copied original image to renamed_images/300.png
# Saved mask for img_0104_jpeg.rf.716185da99584d50b20d2e048bcc352a.jpg to masks/301_mask.png
# Copied original image to renamed_images/301.png
# Saved mask for img_0086_jpeg.rf.6f8a9e9dea1f39a8c1520a8bd6e40143.jpg to masks/302_mask.png
# Copied original image to renamed_images/302.png
# Saved mask for d9c27d7e3de5f11bae1f2b35b4f80ff4_jpg.rf.71b2f213fe443b3f690a72587bb897b6.jpg to masks/303_mask.png
# Copied original image to renamed_images/303.png
# Saved mask for 783795b1e7184e845b89fa908ce99fab_jpg.rf.72b4d7755eb116b739efc898c90bcbe4.jpg to masks/304_mask.png
# Copied original image to renamed_images/304.png
# Saved mask for f6748e4a4351cec112a96a84acad8118_jpg.rf.71feca5c35c2465cbe857b29d7363652.jpg to masks/305_mask.png
# Copied original image to renamed_images/305.png
# ...
# Copied original image to renamed_images/647.png
# Saved mask for img_0138_jpeg.rf.ba54c4f9e096b371d9ae8e934d612af1.jpg to masks/648_mask.png
# Copied original image to renamed_images/648.png
# Saved mask for e32d4ef901d79b9a68ccd352729ec1f2_jpg.rf.bbaea0fb25ca2a3db2f103c6cde5e7cc.jpg to masks/649_mask.png
# Copied original image to renamed_images/649.png
# Saved mask for img_0552_jpeg.rf.baa83e79d6c7843a7221e94a55c38707.jpg to masks/650_mask.png
# Copied original image to renamed_images/650.png
# Saved mask for ed53e55790431be00ad38d6548f70f93_jpg.rf.ba0ad548b7d4dae1e129058905aab98e.jpg to masks/651_mask.png
# Copied original image to renamed_images/651.png
# Saved mask for 1f0d72ecd966170babc209b45abe8983_jpg.rf.bbf0cbbba8104fbed93522995b1a360a.jpg to masks/652_mask.png
# Copied original image to renamed_images/652.png
# Saved mask for f6430ab343c525b6339b631e38af1818_jpg.rf.bcef05a8b4b0d1805fbf325226d51b7a.jpg to masks/653_mask.png
# Copied original image to renamed_images/653.png
# Saved mask for cabf8dee80bf68e1d9936fb5990b648e_jpg.rf.bcc313ef3c70093696347188522b586d.jpg to masks/654_mask.png
# Copied original image to renamed_images/654.png
# Saved mask for fcbbcf0191ab925aa67604ff0c7f141e_jpg.rf.be1d8082ccdbdf1d6fa4db44e90525c9.jpg to masks/655_mask.png
# Copied original image to renamed_images/655.png
# Saved mask for c94bad728fa7917df779c57c24bd0a8d_jpg.rf.bf623f051af33ec0cbb551f488ee6c71.jpg to masks/656_mask.png
# Copied original image to renamed_images/656.png
# Saved mask for ea7d79170bd7f75878c4f492d2475d46_jpg.rf.bf572df66fafaae2032eb3fcc368f5d9.jpg to masks/657_mask.png
# Copied original image to renamed_images/657.png
# Saved mask for c6945a04fa8add48266a7101a4de5215_jpg.rf.be5b5c9adddbd341044333e0a1313ca6.jpg to masks/658_mask.png
# Copied original image to renamed_images/658.png
# Saved mask for 3dcad4616d0f70f5a20f27dd5f552328_jpg.rf.bf698180884e4715819ea7daf16db63c.jpg to masks/659_mask.png
# Copied original image to renamed_images/659.png
# Saved mask for img_0146_jpeg.rf.bfda44323d88c1c8088a497b332b4459.jpg to masks/660_mask.png
# Copied original image to renamed_images/660.png
# Saved mask for img_0011_jpeg.rf.bf959651d39ae04a649fffe28035081f.jpg to masks/661_mask.png
# Copied original image to renamed_images/661.png
# Saved mask for 3ba29aa7a1df892139f4006867bda2be_jpg.rf.c01ea304dde14c8c21b4f7e8ec445961.jpg to masks/662_mask.png
# Copied original image to renamed_images/662.png
# Saved mask for fcc71ab647c43d3bdae6ba5e9349464d_jpg.rf.bdf84c35bb2281a1ccc652c8dcc82e4c.jpg to masks/663_mask.png
# Copied original image to renamed_images/663.png
# Saved mask for d4c344f311d15ca6651e300873a356c0_jpg.rf.c0c6b09f2bb14ca1191d5e730ffe8b88.jpg to masks/664_mask.png
# Copied original image to renamed_images/664.png
# Saved mask for fb914394a5b417b680b3201d1bf162a1_jpg.rf.c02b3b6a40a24b81b371367a1b88edf0.jpg to masks/665_mask.png
# Copied original image to renamed_images/665.png
# Saved mask for fbd984ec15a9276bacd93971a21025d6_jpg.rf.c0925931bfb5e3773fab631f8200c3fc.jpg to masks/666_mask.png
# Copied original image to renamed_images/666.png
# Saved mask for e95f3ff180acbafd75ffea1032e798a5_jpg.rf.c18a4e9700a0afb2da6a31115efdca3b.jpg to masks/667_mask.png
# Copied original image to renamed_images/667.png
# Saved mask for 0ead2ad663e32a0f867c31895b1ade76_jpg.rf.c1df0e8d4856b34cbbf513621f8301df.jpg to masks/668_mask.png
# Copied original image to renamed_images/668.png
# Saved mask for 1e3fe6a399b928aa949bffe392ffe367_jpg.rf.c0d26fd4abf672ca1c83c38cb9062fcc.jpg to masks/669_mask.png
# Copied original image to renamed_images/669.png
# Saved mask for d3822d2c41fd9b044ba0f933f2ef2a42_jpg.rf.c2c2bbf01ece3d8f887e9fca6412917a.jpg to masks/670_mask.png
# Copied original image to renamed_images/670.png
# Saved mask for 42e223bd6f6a6b8dce57c4496ca4fcc2_jpg.rf.c0f268ff44fac49d9b99473f6342fade.jpg to masks/671_mask.png
# Copied original image to renamed_images/671.png
# Saved mask for dbdc279b55d47a369ca44505677d6f51_jpg.rf.c19e47d927fc38fea4d2e85616ea94ef.jpg to masks/672_mask.png
# Copied original image to renamed_images/672.png
# Saved mask for 17e3e8454e1addcf98b2449ccb96d3a9_jpg.rf.c390f770cb0a0bd67e7f68eeca159030.jpg to masks/673_mask.png
# Copied original image to renamed_images/673.png
# Saved mask for 2ceacea255bd16e687e26a83c5452255_jpg.rf.c5f06499ae078b39e127f2daac95cecc.jpg to masks/674_mask.png
# Copied original image to renamed_images/674.png
# Saved mask for img_0140_jpeg.rf.c5f08f3baed08be6914691583eb16015.jpg to masks/675_mask.png
# Copied original image to renamed_images/675.png
# Copied original image to renamed_images/693.png
# Saved mask for e318e8f1318753208d4c26bd46f3be08_jpg.rf.cd6c882412fdb100ac32b82f07e99448.jpg to masks/694_mask.png
# Copied original image to renamed_images/694.png
# Saved mask for db26dd4ab74b3f12041cc72ff6acb60d_jpg.rf.cf83b9ee57e1bcfa6dc8a9852da0641a.jpg to masks/695_mask.png
# Copied original image to renamed_images/695.png
# Saved mask for ff6884bdb45a9aca6df20885e950eb1f_jpg.rf.cecba2fb16f1eca1553e097f5d54df49.jpg to masks/696_mask.png
# Copied original image to renamed_images/696.png
# Saved mask for e4de7821071dd5b1baa80bb9813a8895_jpg.rf.cd483efc7ca7d4caefad7eab4e961097.jpg to masks/697_mask.png
# Copied original image to renamed_images/697.png
# Saved mask for img_0173_jpeg.rf.cfc28d17653b6079ab585c3f26108dd8.jpg to masks/698_mask.png
# Copied original image to renamed_images/698.png
# Saved mask for img_0215_jpeg.rf.cfa90896bdb4272a95e205175d13fc7a.jpg to masks/699_mask.png
# Copied original image to renamed_images/699.png
# Saved mask for e2ba4d1e422cc766d9e8eaacd3a25a3e_jpg.rf.d0441a6d0a056c4754e23425c60d86d4.jpg to masks/700_mask.png
# Copied original image to renamed_images/700.png
# Saved mask for fd860a8100f35a28da87cec4c565ecdd_jpg.rf.d013e9d2584264bbe2717e4b5941708a.jpg to masks/701_mask.png
# Copied original image to renamed_images/701.png
# Saved mask for 4caf9a623b8931bf6b2f6107af4381fb_jpg.rf.cfebc9521d58ebf5367a80a7e562970d.jpg to masks/702_mask.png
# Copied original image to renamed_images/702.png
# Saved mask for img_0802_jpeg.rf.cfcb78176dabf8c727c1936888ef1a2b.jpg to masks/703_mask.png
# Copied original image to renamed_images/703.png
# Saved mask for 34200ca626775c549932ff37b1fd1875_jpg.rf.d05ec1160a7dbdc0dbf29cb0387d18ee.jpg to masks/704_mask.png
# Copied original image to renamed_images/704.png
# Saved mask for 0dc0c471a32907df9e6f3f85b1d1897b_jpg.rf.d089089fcaf4ea3e61e0298dde6932cc.jpg to masks/705_mask.png
# Copied original image to renamed_images/705.png
# Saved mask for d3ffb8841f721835559ecdedeefd2387_jpg.rf.d1bf24b49d64406b7f03ff984a7f5174.jpg to masks/706_mask.png
# Copied original image to renamed_images/706.png
# Saved mask for 3a7a87b0596e88cca11916a7bc59c50c_jpg.rf.d0e352efd980c59f1eb84403ce8c2101.jpg to masks/707_mask.png
# Copied original image to renamed_images/707.png
# Saved mask for d2b54bddb408aa4b652b402aefb1dd7e_jpg.rf.d0e28f39a41638578d43fcd82b9fd6f2.jpg to masks/708_mask.png
# Copied original image to renamed_images/708.png
# Saved mask for f30531a4d58a68754ce74db77740b191_jpg.rf.d1d1a1f22c42510aaf739f2ce9f1727f.jpg to masks/709_mask.png
# Copied original image to renamed_images/709.png
# Saved mask for 1dffba470396e2e75841783f4584ed86_jpg.rf.d26a79baaaf505442eab7d7892cfaef6.jpg to masks/710_mask.png
# Copied original image to renamed_images/710.png
# Saved mask for feffaa7a759648ef521ace8d7b219fd1_jpg.rf.dc0fa0f1789176b462ff924d0d65bde1.jpg to masks/746_mask.png
# Copied original image to renamed_images/746.png
# Saved mask for img_0574_jpeg.rf.dc830a80fa0e8fdf4a4420adb7d8c729.jpg to masks/747_mask.png
# Copied original image to renamed_images/747.png
# Saved mask for f8e06447cc09b99b019e6115ac68d633_jpg.rf.db2e15d511e7d7cd96c9366031dba791.jpg to masks/748_mask.png
# Copied original image to renamed_images/748.png

# %%
from PIL import Image
import os

def resize_images(input_dir, output_dir, output_size=(640, 640)):
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # List all files in the input directory
    files = os.listdir(input_dir)
    
    # Iterate through each file in the input directory
    for file in files:
        # Check if the file is a PNG image
        if file.endswith('.png'):
            # Open the image using PIL
            image_path = os.path.join(input_dir, file)
            img = Image.open(image_path)
            
            # Resize the image to the desired output size
            resized_img = img.resize(output_size)
            
            # Save the resized image to the output directory
            output_path = os.path.join(output_dir, file)
            resized_img.save(output_path)


# Example usage:
input_directory = "/Users/harishsatheesh/Clothing-Style-transfer/clothing_style_transfer"
output_directory = "/Users/harishsatheesh/Clothing-Style-transfer/new"
resize_images(input_directory, output_directory)

# %%
import cv2
def concatenate_images(background_image, overlay_image, position=(0, 0)):
    # Extract the alpha channel from the overlay image
    overlay_alpha = overlay_image[:, :, 3]

    # Convert the overlay alpha channel to the same data type as the background image
    overlay_alpha = overlay_alpha.astype(background_image.dtype)

    # Resize the overlay image if it is larger than the background image
    overlay_height, overlay_width, _ = overlay_image.shape
    bg_height, bg_width, _ = background_image.shape
    if overlay_height > bg_height or overlay_width > bg_width:
        overlay_image = cv2.resize(overlay_image, (bg_width, bg_height))

    # Get the position where the overlay image will be placed
    y, x = position

    # Create a region of interest (ROI) for the overlay on the background image
    roi = background_image[y:y+overlay_height, x:x+overlay_width]

    # Blend the overlay image with the background using the alpha channel
    blended_overlay = cv2.bitwise_and(overlay_image[:, :, :3], overlay_image[:, :, :3], mask=overlay_alpha)
    blended_background = cv2.bitwise_and(roi, roi, mask=cv2.bitwise_not(overlay_alpha))
    blended_roi = cv2.add(blended_overlay, blended_background)

    # Update the background image with the blended ROI
    background_image[y:y+overlay_height, x:x+overlay_width] = blended_roi

    return background_image

# Example usage
background_image = cv2.imread("/Users/harishsatheesh/Clothing-Style-transfer/images/9.png", cv2.IMREAD_UNCHANGED)
overlay_image = cv2.imread("new/9_mask+wave-0.png", cv2.IMREAD_UNCHANGED)

# Concatenate the images with the overlay image positioned at (100, 100)
result_image = concatenate_images(background_image, overlay_image, position=(100, 100))

# Display the result
cv2.imshow("Result", result_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[16], line 38
#      35 overlay_image = cv2.imread("new/9_mask+wave-0.png", cv2.IMREAD_UNCHANGED)
#      37 # Concatenate the images with the overlay image positioned at (100, 100)
# ---> 38 result_image = concatenate_images(background_image, overlay_image, position=(100, 100))
#      40 # Display the result
#      41 cv2.imshow("Result", result_image)
#
# Cell In[16], line 25, in concatenate_images(background_image, overlay_image, position)
#      23 # Blend the overlay image with the background using the alpha channel
#      24 blended_overlay = cv2.bitwise_and(overlay_image[:, :, :3], overlay_image[:, :, :3], mask=overlay_alpha)
# ---> 25 blended_background = cv2.bitwise_and(roi, roi, mask=cv2.bitwise_not(overlay_alpha))
#      26 blended_roi = cv2.add(blended_overlay, blended_background)
#      28 # Update the background image with the blended ROI
#
# error: OpenCV(4.5.3) /Users/runner/miniforge3/conda-bld/libopencv_1630689852376/work/modules/core/src/arithm.cpp:230: error: (-215:Assertion failed) (mtype == CV_8U || mtype == CV_8S) && _mask.sameSize(*psrc1) in function 'binary_op'

# %%
from PIL import Image

# Load the mask image
mask_image_path = "/Users/harishsatheesh/Clothing-Style-transfer/clothing_style_transfer/9_mask+wave-7.png"
mask_image = Image.open(mask_image_path).convert("RGBA")

# Load the original image
original_image_path = "/Users/harishsatheesh/Clothing-Style-transfer/images/9.png"
original_image = Image.open(original_image_path).convert("RGBA")

# Resize the mask image to match the size of the original image
mask_image_resized = mask_image.resize(original_image.size)

# Overlay the resized mask image onto the original image
result_image = Image.alpha_composite(original_image, mask_image_resized)

# Save the result
result_image_path = "/Users/harishsatheesh/Clothing-Style-transfer/overlay_result_structure.png"
result_image.save(result_image_path)

print("Overlay complete. Result saved at:", result_image_path)
# Out:
# Overlay complete. Result saved at: /Users/harishsatheesh/Clothing-Style-transfer/overlay_result_structure.png

# %%
import json
import numpy as np
import skimage
import os
from PIL import Image
import skimage.draw

def extract_and_overlay_pixels(image_info, annotations, style_transfer_image_path, output_folder):
    # Load the style transferred image
    style_transfer_img = Image.open(style_transfer_image_path)

    # Create an overlay as a numpy array with transparency (RGBA)
    overlay_np = np.zeros((image_info['height'], image_info['width'], 4), dtype=np.uint8)  # RGBA format
    # Iterate through annotations
    for ann in annotations:
        if ann['image_id'] == image_info['id']:
            # Extract segmentation polygon
            for seg in ann['segmentation']:
                # Convert polygons to a binary mask
                rr, cc = skimage.draw.polygon(seg[1::2], seg[0::2], overlay_np.shape[:2])
                # Extract corresponding pixels from the style transferred image
                style_transfer_pixels = np.array(style_transfer_img)
                extracted_pixels = style_transfer_pixels[rr, cc]
                # Overlay the extracted pixels on the overlay image
                overlay_np[rr, cc, :3] = extracted_pixels
                overlay_np[rr, cc, 3] = 255  # Set alpha channel to fully opaque

    # Save the numpy array as a PNG image with transparency
    overlay_path = os.path.join(output_folder, "{}_overlay.png".format(image_info['id']))
    overlay_img = Image.fromarray(overlay_np, mode='RGBA')  # Use mode 'RGBA' for color images with transparency
    overlay_img.save(overlay_path)
    print(f"Saved overlay for {image_info['file_name']} to {overlay_path}")

    # Overlay the extracted pixels on the original image
    original_image_path = os.path.join(original_image_dir, "{}.png".format(image_info['id']))
    original_img = Image.open(original_image_path)
    result_img = Image.alpha_composite(original_img.convert('RGBA'), overlay_img)
    result_path = os.path.join(output_folder, "{}_result.png".format(image_info['id']))
    result_img.save(result_path)
    print(f"Saved result image for {image_info['file_name']} to {result_path}")

def main(json_file, style_transfer_image_path, output_folder, original_image_dir):
    # Load COCO JSON annotations
    with open(json_file, 'r') as f:
        data = json.load(f)

    images = data['images']
    annotations = data['annotations']

    # Ensure the output directory exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for img in images:
        # Extract and overlay pixels, and save the result
        extract_and_overlay_pixels(img, annotations, style_transfer_image_path, output_folder)

if __name__ == '__main__':
    original_image_dir = '/Users/harishsatheesh/Clothing-Style-transfer/images'  # Where your original images are stored
    json_file = '/Users/harishsatheesh/Clothing-Style-transfer/train/_annotations.coco.json'
    style_transfer_image_path = '/Users/harishsatheesh/Clothing-Style-transfer/new/9_mask+wave-0.png'  # Path to the style transferred image
    output_folder = '/Users/harishsatheesh/Clothing-Style-transfer/overlay_results'  # Output folder for overlay results
    main(json_file, style_transfer_image_path, output_folder, original_image_dir)

# %%
import os
import json
import numpy as np
from PIL import Image
import skimage.draw

def overlay_masks_on_original_images(annotations_file, original_image_dir, style_transferred_mask_dir, output_folder):
    # Load annotations from JSON file
    with open(annotations_file, 'r') as f:
        annotations_data = json.load(f)

    # Filter annotations for images in the content directory with specific IDs
    content_ids = [6, 9, 12, 25, 29]
    filtered_annotations = [ann for ann in annotations_data['annotations'] if ann['image_id'] in content_ids]

    # Iterate over each filtered annotation
    for ann in filtered_annotations:
        # Find the original image corresponding to this annotation
        original_image_path = os.path.join(original_image_dir, f"{ann['image_id']}_mask.png")
        
        # Load the original image
        original_img = Image.open(original_image_path)

        # Find the style transferred mask corresponding to this original image
        style_transferred_mask_files = [file for file in os.listdir(style_transferred_mask_dir) if file.startswith(f"{ann['image_id']}")]
        
        # Iterate over style transferred mask files
        for style_transferred_mask_file in style_transferred_mask_files:
            # Load the style transferred mask
            style_transferred_mask_path = os.path.join(style_transferred_mask_dir, style_transferred_mask_file)
            style_transfer_img = Image.open(style_transferred_mask_path)

            # Convert style transferred mask image to RGBA format if not already in RGBA format
            if style_transfer_img.mode != 'RGBA':
                style_transfer_img = style_transfer_img.convert('RGBA')

            # Ensure that the style transferred mask image has the same dimensions as the original image
            style_transfer_img = style_transfer_img.resize(original_img.size)

            # Initialize an overlay image as a numpy array
            overlay_np = np.array(original_img)

            # Extract segmentation polygons from the annotation
            for seg in ann['segmentation']:
                # Convert polygons to a binary mask
                rr, cc = skimage.draw.polygon(seg[1::2], seg[0::2], overlay_np.shape[:2])

                # Extract corresponding pixels from the style transferred image
                style_transfer_pixels = np.array(style_transfer_img)
                extracted_pixels = style_transfer_pixels[rr, cc]

                # Overlay the extracted pixels on the overlay image
                overlay_np[rr, cc, :4] = extracted_pixels  # Include alpha channel

            # Convert overlay numpy array back to PIL image
            overlay_img = Image.fromarray(overlay_np)

            # Save the blended image
            blended_img_path = os.path.join(output_folder, f"{ann['image_id']}_{style_transferred_mask_file}_blended.png")
            overlay_img.save(blended_img_path)

# Example usage:
annotations_file = 'train/_annotations.coco.json'
original_image_dir = 'clothing_style_transfer/content'
style_transferred_mask_dir = 'result_masks'
output_folder = 'blended_images'

overlay_masks_on_original_images(annotations_file, original_image_dir, style_transferred_mask_dir, output_folder)

# %%
import os
import json
import numpy as np
from PIL import Image

def overlay_masks_on_original_images(annotations_file, original_image_dir, style_transferred_mask_dir, output_folder):
    # Load annotations from JSON file
    with open(annotations_file, 'r') as f:
        annotations_data = json.load(f)

    # Filter annotations for images in the content directory with specific IDs
    content_ids = [6, 9, 12, 25, 29]
    filtered_annotations = [ann for ann in annotations_data['annotations'] if ann['image_id'] in content_ids]

    # Iterate over each filtered annotation
    for ann in filtered_annotations:
        # Find the original image corresponding to this annotation
        original_image_path = os.path.join(original_image_dir, f"{ann['image_id']}_mask.png")
        
        # Load the original image
        original_img = Image.open(original_image_path)

        # Find the style transferred mask corresponding to this original image
        style_transferred_mask_files = [file for file in os.listdir(style_transferred_mask_dir) if file.startswith(f"{ann['image_id']}")]
        
        # Iterate over style transferred mask files
        for style_transferred_mask_file in style_transferred_mask_files:
            # Load the style transferred mask
            style_transferred_mask_path = os.path.join(style_transferred_mask_dir, style_transferred_mask_file)
            style_transfer_img = Image.open(style_transferred_mask_path)

            # Convert style transferred mask image to RGBA format if not already in RGBA format
            if style_transfer_img.mode != 'RGBA':
                style_transfer_img = style_transfer_img.convert('RGBA')

            # Ensure that the style transferred mask image has the same dimensions as the original image
            style_transfer_img = style_transfer_img.resize(original_img.size)

            # Create a mask where only the opaque pixels are considered
            mask = np.array(style_transfer_img)[:, :, 3] > 0

            # Apply the mask to the style transferred image
            style_transfer_img = np.array(style_transfer_img)
            style_transfer_img[mask == False] = [0, 0, 0, 0]

            # Convert the style transferred image back to PIL format
            style_transfer_img = Image.fromarray(style_transfer_img)

            # Blend the style transferred image with the original image
            blended_img = Image.alpha_composite(original_img.convert('RGBA'), style_transfer_img)

            # Save the blended image
            blended_img_path = os.path.join(output_folder, f"{ann['image_id']}_{style_transferred_mask_file}_blended.png")
            blended_img.save(blended_img_path)

# Example usage:
annotations_file = 'train/_annotations.coco.json'
original_image_dir = 'clothing_style_transfer/content'
style_transferred_mask_dir = 'result_masks'
output_folder = 'blended_images'

overlay_masks_on_original_images(annotations_file, original_image_dir, style_transferred_mask_dir, output_folder)

# %%
import os
import json
import numpy as np
from PIL import Image
import skimage.draw

def overlay_masks_on_original_images(annotations_file, original_image_dir, style_transferred_mask_dir, output_folder):
    # Load annotations from JSON file
    with open(annotations_file, 'r') as f:
        annotations_data = json.load(f)

    # Filter annotations for images in the content directory with specific IDs
    content_ids = [6, 9, 12, 25, 29]
    filtered_annotations = [ann for ann in annotations_data['annotations'] if ann['image_id'] in content_ids]

    # Iterate over each filtered annotation
    for ann in filtered_annotations:
        # Find the original image corresponding to this annotation
        original_image_path = os.path.join(original_image_dir, f"{ann['image_id']}.png")
        
        # Load the original image
        original_img = Image.open(original_image_path)

        # Find the style transferred mask corresponding to this original image
        style_transferred_mask_files = [file for file in os.listdir(style_transferred_mask_dir) if file.startswith(f"{ann['image_id']}")]
        
        # Iterate over style transferred mask files
        for style_transferred_mask_file in style_transferred_mask_files:
            # Load the style transferred mask
            style_transferred_mask_path = os.path.join(style_transferred_mask_dir, style_transferred_mask_file)
            style_transferred_mask = Image.open(style_transferred_mask_path).convert("RGBA")

            # Resize the mask image to match the size of the original image
            mask_image_resized = style_transferred_mask.resize(original_img.size)

            # Initialize a mask numpy array
            mask_np = np.array(mask_image_resized)

            # Extract segmentation polygons from the annotation
            for seg in ann['segmentation']:
                # Convert polygons to a binary mask and add it to the main mask
                rr, cc = skimage.draw.polygon(seg[1::2], seg[0::2], mask_np.shape[:2])
                # Get the original RGB pixel values from the loaded image
                original_pixels = np.array(original_img)
                # Extract only the RGB channels from original pixel values
                original_rgb_pixels = original_pixels[rr, cc, :3]
                # Assign original pixel values to the mask, including transparency (alpha channel)
                mask_np[rr, cc, :3] = original_rgb_pixels 
                mask_np[rr, cc, 3] = 255  # Set alpha channel to fully opaque

            # Convert mask numpy array back to PIL image
            overlay_img = Image.fromarray(mask_np, 'RGBA')

            # Save the blended image
            blended_img_path = os.path.join(output_folder, f"{ann['image_id']}_{style_transferred_mask_file}_blended.png")
            overlay_img.save(blended_img_path)

# Example usage:
annotations_file = 'train/_annotations.coco.json'
original_image_dir = 'content'
style_transferred_mask_dir = 'result_masks'
output_folder = 'blended_images'

overlay_masks_on_original_images(annotations_file, original_image_dir, style_transferred_mask_dir, output_folder)

# %%
import os
import json
from PIL import Image

def overlay_masks_on_original_images(annotations_file, original_image_dir, mask_image_dir, output_folder):
    # Load annotations from JSON file
    with open(annotations_file, 'r') as f:
        annotations_data = json.load(f)

    # Create a dictionary to map each original image ID to its corresponding mask images
    mask_images_dict = {}
    for mask_image_file in os.listdir(mask_image_dir):
        if not mask_image_file.endswith('.png'):
            continue
        image_id = mask_image_file.split('_')[0]  # Extract the image ID
        if image_id not in mask_images_dict:
            mask_images_dict[image_id] = []
        mask_images_dict[image_id].append(mask_image_file)

    # Iterate over each original image
    for image_file in os.listdir(original_image_dir):
        if not image_file.endswith('.png'):
            continue
        image_id = image_file.split('.')[0]  # Extract the image ID

        # Find the original image corresponding to this ID
        original_image_path = os.path.join(original_image_dir, image_file)
        
        # Load the original image
        original_img = Image.open(original_image_path).convert("RGBA")

        # Check if there are mask images corresponding to this original image ID
        if image_id in mask_images_dict:
            # Iterate over each mask image
            for mask_image_file in mask_images_dict[image_id]:
                # Load the mask image
                mask_image_path = os.path.join(mask_image_dir, mask_image_file)
                mask_img = Image.open(mask_image_path).convert("RGBA")

                # Resize the mask image to match the size of the original image
                mask_img_resized = mask_img.resize(original_img.size)

                # Overlay the resized mask image onto the original image
                result_img = Image.alpha_composite(original_img, mask_img_resized)

                # Save the result
                result_image_path = os.path.join(output_folder, f"{image_id}_{mask_image_file}_overlay_result.png")
                result_img.save(result_image_path)

                print(f"Overlay complete for original image {image_id} with mask {mask_image_file}. Result saved at: {result_image_path}")
        else:
            print(f"No mask images found for original image {image_id}")

# Example usage:
annotations_file = 'train/_annotations.coco.json'
original_image_dir = 'content'
mask_image_dir = 'result_masks'
output_folder = 'blended_images'

overlay_masks_on_original_images(annotations_file, original_image_dir, mask_image_dir, output_folder)
# Out:
# Overlay complete for original image 9 with mask 9_mask+art+60-8.png. Result saved at: blended_images/9_9_mask+art+60-8.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+art+60-9.png. Result saved at: blended_images/9_9_mask+art+60-9.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+wave-0.png. Result saved at: blended_images/9_9_mask+wave-0.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+wave-7.png. Result saved at: blended_images/9_9_mask+wave-7.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+art-1.png. Result saved at: blended_images/9_9_mask+art-1.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+art+60-7.png. Result saved at: blended_images/9_9_mask+art+60-7.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+art+60-6.png. Result saved at: blended_images/9_9_mask+art+60-6.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+art+60-4.png. Result saved at: blended_images/9_9_mask+art+60-4.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+art+60-5.png. Result saved at: blended_images/9_9_mask+art+60-5.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+art+60-1.png. Result saved at: blended_images/9_9_mask+art+60-1.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+art+60-0.png. Result saved at: blended_images/9_9_mask+art+60-0.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+art+60-2.png. Result saved at: blended_images/9_9_mask+art+60-2.png_overlay_result.png
# Overlay complete for original image 9 with mask 9_mask+art+60-3.png. Result saved at: blended_images/9_9_mask+art+60-3.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+art-9.png. Result saved at: blended_images/29_29_mask+art-9.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+art-8.png. Result saved at: blended_images/29_29_mask+art-8.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+scream-9.png. Result saved at: blended_images/29_29_mask+scream-9.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+scream-8.png. Result saved at: blended_images/29_29_mask+scream-8.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+wave-9.png. Result saved at: blended_images/29_29_mask+wave-9.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+wave-8.png. Result saved at: blended_images/29_29_mask+wave-8.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+wave-0.png. Result saved at: blended_images/29_29_mask+wave-0.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+wave-1.png. Result saved at: blended_images/29_29_mask+wave-1.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+wave-3.png. Result saved at: blended_images/29_29_mask+wave-3.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+wave-2.png. Result saved at: blended_images/29_29_mask+wave-2.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+wave-6.png. Result saved at: blended_images/29_29_mask+wave-6.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+wave-7.png. Result saved at: blended_images/29_29_mask+wave-7.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+wave-5.png. Result saved at: blended_images/29_29_mask+wave-5.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+wave-4.png. Result saved at: blended_images/29_29_mask+wave-4.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+art-0.png. Result saved at: blended_images/29_29_mask+art-0.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+scream-3.png. Result saved at: blended_images/29_29_mask+scream-3.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+scream-2.png. Result saved at: blended_images/29_29_mask+scream-2.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+art-1.png. Result saved at: blended_images/29_29_mask+art-1.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+art-3.png. Result saved at: blended_images/29_29_mask+art-3.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+scream-0.png. Result saved at: blended_images/29_29_mask+scream-0.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+scream-1.png. Result saved at: blended_images/29_29_mask+scream-1.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+art-2.png. Result saved at: blended_images/29_29_mask+art-2.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask+art-6.png. Result saved at: blended_images/29_29_mask+art-6.png_overlay_result.png
# Overlay complete for original image 29 with mask 29_mask